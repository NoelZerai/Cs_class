# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
housing_df = pd.read_csv('Housing.csv')
housing_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[62], line 2
#       1 pd.set_option('display.max_columns', None)
# ----> 2 housing_df = pd.read_csv('Housing.csv')
#       3 housing_df.head()
#
# ...

# %%
housing_df = sp_df.dropna()
housing_df.drop(['id','sqft_living','sqft_lot','waterfront','date'], axis=1, inplace = True)
housing_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 2
#       1 housing_df = sp_df.dropna()
# ----> 2 housing_df.drop(['id','sqft_living','sqft_lot','waterfront','date'], axis=1, inplace = True)
#       3 housing_df.head()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
# ...
