# %%
#1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
class_survey_df = pd.read_csv('CSCI_1070_survey_results-2.csv')
class_survey_df.head()
# Out:
#                     Timestamp What is your name?  \
# 0   2024/01/29 6:34:23 PM CST      Gavin Edwards
# 1   2024/01/29 6:46:07 PM CST                NaN
# 2   2024/01/29 7:45:39 PM CST        Connor Love
# 3   2024/01/29 7:47:12 PM CST               Liam
# 4  2024/01/29 10:45:38 PM CST  Aarushi Choudhary
#
#   What state/country were you born in? Are you working while in school?  \
# 0                             Missouri                              Yes
# 1                Saint Louis, Missouri                              Yes
# 2                             Illinois                               No
# 3                             Missouri                              Yes
# 4                                Japan                              Yes
#
#   How much experience do you have programming? What class are you in?   \
# 0                            6 months - 1 year                Freshman
# 1                                   0-3 months                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have?  \
# 0                              1
# 1                              2
# 2                              1
# 3                              1
# 4                              1
#
#         How many pets and of which kind do you have?  \
# 0              I have two dogs both chihuahua mixes.
# 1                                                  0
# 2  I have two golden retrievers, Ellie and Amber....
# 3                                                  0
# 4                                            No pets
#
#   What is your favorite type of food? Where do you live?  \
# 0   Pasta but fish is a close second.          On campus
# 1                           Hot wings         Off campus
# 2                            Mexican.          On campus
# 3                          Vietnamese         Off campus
# 4                               Pasta          On campus
#
#   Do you take the metro?     What is your major? How old are you?  \
# 0                     No           Data Science                18
# 1                     No                 Nursing               19
# 2                     No  Economics and Finance.               19
# 3                     No            Biochemistry               18
# 4                    Yes         Health Sciences               18
#
#   What is your favorite TV show? What is your favorite video game?  \
# 0                   Breaking Bad                     Rocket League
# 1                 Criminal Minds                          Valorant
# 2                      The Wire.                  Pokémon White 2.
# 3                            NaN                               NaN
# 4                            NaN                       Spiderman 2
#
#           What is your favorite book?  \
# 0                   The Scythe series
# 1    A Little life by Hanya Yanaghara
# 2  "Surprised by Joy" by C. S. Lewis.
# 3                                 NaN
# 4                                 NaN
#
#                      Why are you taking this class?   \
# 0      Its a requirement for the data science major.
# 1  I have an interest in programming. I enjoy lea...
# 2  Transfer course requirements for the Universit...
# 3                                      Applicability
# 4          I'm trying to get a minor in data science
#
#     Whats your favorite bash command?
# 0                                  ls
# 1                                 NaN
# 2  <git push> by far, too satisfying.
# 3                                 NaN
# 4                                  ls

# %%
#2
class_survey_df['country/state'] = np.where(class_survey_df['What state/country were you born in?'] == 'Japan', 'Japan',
                                     np.where(class_survey_df['What state/country were you born in?'] == 'Illnois', 'Illnois',
                                             np.where(class_survey_df['What state/country were you born in?'] == 'Missouri', 'Missouri','USA')))
class_survey_df.head()
# Out:
#                     Timestamp What is your name?  \
# 0   2024/01/29 6:34:23 PM CST      Gavin Edwards
# 1   2024/01/29 6:46:07 PM CST                NaN
# 2   2024/01/29 7:45:39 PM CST        Connor Love
# 3   2024/01/29 7:47:12 PM CST               Liam
# 4  2024/01/29 10:45:38 PM CST  Aarushi Choudhary
#
#   What state/country were you born in? Are you working while in school?  \
# 0                             Missouri                              Yes
# 1                Saint Louis, Missouri                              Yes
# 2                             Illinois                               No
# 3                             Missouri                              Yes
# 4                                Japan                              Yes
#
#   How much experience do you have programming? What class are you in?   \
# 0                            6 months - 1 year                Freshman
# 1                                   0-3 months                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have?  \
# 0                              1
# 1                              2
# 2                              1
# 3                              1
# 4                              1
#
#         How many pets and of which kind do you have?  \
# 0              I have two dogs both chihuahua mixes.
# 1                                                  0
# 2  I have two golden retrievers, Ellie and Amber....
# 3                                                  0
# 4                                            No pets
#
#   What is your favorite type of food? Where do you live?  \
# 0   Pasta but fish is a close second.          On campus
# 1                           Hot wings         Off campus
# 2                            Mexican.          On campus
# 3                          Vietnamese         Off campus
# 4                               Pasta          On campus
#
#   Do you take the metro?     What is your major? How old are you?  \
# 0                     No           Data Science                18
# 1                     No                 Nursing               19
# 2                     No  Economics and Finance.               19
# 3                     No            Biochemistry               18
# 4                    Yes         Health Sciences               18
#
#   What is your favorite TV show? What is your favorite video game?  \
# 0                   Breaking Bad                     Rocket League
# 1                 Criminal Minds                          Valorant
# 2                      The Wire.                  Pokémon White 2.
# 3                            NaN                               NaN
# 4                            NaN                       Spiderman 2
#
#           What is your favorite book?  \
# 0                   The Scythe series
# 1    A Little life by Hanya Yanaghara
# 2  "Surprised by Joy" by C. S. Lewis.
# 3                                 NaN
# 4                                 NaN
#
#                      Why are you taking this class?   \
# 0      Its a requirement for the data science major.
# 1  I have an interest in programming. I enjoy lea...
# 2  Transfer course requirements for the Universit...
# 3                                      Applicability
# 4          I'm trying to get a minor in data science
#
#     Whats your favorite bash command? country/state
# 0                                  ls      Missouri
# 1                                 NaN           USA
# 2  <git push> by far, too satisfying.           USA
# 3                                 NaN      Missouri
# 4                                  ls         Japan

# %%
#3
class_survey_df = class_survey_df.dropna(subset=['How many pets and of which kind do you have?'])
class_survey_df['How many pets and of which kind do you have?'].str.contains('none', '0')
class_survey_df['Dogs'] = np.where(class_survey_df['How many pets and of which kind do you have?'].str.contains('dog'), '1','0')
class_survey_df['Cats'] = np.where(class_survey_df['How many pets and of which kind do you have?'].str.contains('cat'), '1','0')
class_survey_df['Other_pets'] = np.where(class_survey_df['How many pets and of which kind do you have?'].str.contains('tutle'), '1','0')
class_survey_df.head()
# Out:
#                     Timestamp What is your name?  \
# 0   2024/01/29 6:34:23 PM CST      Gavin Edwards
# 1   2024/01/29 6:46:07 PM CST                NaN
# 2   2024/01/29 7:45:39 PM CST        Connor Love
# 3   2024/01/29 7:47:12 PM CST               Liam
# 4  2024/01/29 10:45:38 PM CST  Aarushi Choudhary
#
#   What state/country were you born in? Are you working while in school?  \
# 0                             Missouri                              Yes
# 1                Saint Louis, Missouri                              Yes
# 2                             Illinois                               No
# 3                             Missouri                              Yes
# 4                                Japan                              Yes
#
#   How much experience do you have programming? What class are you in?   \
# 0                            6 months - 1 year                Freshman
# 1                                   0-3 months                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have?  \
# 0                              1
# 1                              2
# 2                              1
# 3                              1
# 4                              1
#
#         How many pets and of which kind do you have?  \
# 0              I have two dogs both chihuahua mixes.
# 1                                                  0
# 2  I have two golden retrievers, Ellie and Amber....
# 3                                                  0
# 4                                            No pets
#
#   What is your favorite type of food? Where do you live?  ...  \
# 0   Pasta but fish is a close second.          On campus  ...
# 1                           Hot wings         Off campus  ...
# 2                            Mexican.          On campus  ...
# 3                          Vietnamese         Off campus  ...
# 4                               Pasta          On campus  ...
#
#   How old are you? What is your favorite TV show?  \
# 0               18                   Breaking Bad
# 1               19                 Criminal Minds
# 2               19                      The Wire.
# 3               18                            NaN
# 4               18                            NaN
#
#   What is your favorite video game?         What is your favorite book?  \
# 0                     Rocket League                   The Scythe series
# 1                          Valorant    A Little life by Hanya Yanaghara
# 2                  Pokémon White 2.  "Surprised by Joy" by C. S. Lewis.
# 3                               NaN                                 NaN
# 4                       Spiderman 2                                 NaN
#
#                      Why are you taking this class?   \
# 0      Its a requirement for the data science major.
# 1  I have an interest in programming. I enjoy lea...
# 2  Transfer course requirements for the Universit...
# 3                                      Applicability
# 4          I'm trying to get a minor in data science
#
#     Whats your favorite bash command? country/state Dogs Cats Other_pets
# 0                                  ls      Missouri    1    0          0
# 1                                 NaN           USA    0    0          0
# 2  <git push> by far, too satisfying.           USA    0    0          0
# 3                                 NaN      Missouri    0    0          0
# 4                                  ls         Japan    0    0          0
#
# [5 rows x 22 columns]

# %%
#4
class_survey_df = class_survey_df.dropna(subset=['What is your favorite type of food?'])
class_survey_df['What is your favorite type of food?']
cuisine = {'pasta' :' Italian',
           'VVietnamese' : 'Vietnam',
           'Mexican' : 'Mexican',
           'pasta' : 'italian',
           'Injera' : 'Eritrean',
           '' : 'None'}
class_survey_df['Favorite Cuisine'] = class_survey_df['What is your favorite type of food?'].map(cuisine)    
class_survey_df.head()
# Out:
#                     Timestamp What is your name?  \
# 0   2024/01/29 6:34:23 PM CST      Gavin Edwards
# 1   2024/01/29 6:46:07 PM CST                NaN
# 2   2024/01/29 7:45:39 PM CST        Connor Love
# 3   2024/01/29 7:47:12 PM CST               Liam
# 4  2024/01/29 10:45:38 PM CST  Aarushi Choudhary
#
#   What state/country were you born in? Are you working while in school?  \
# 0                             Missouri                              Yes
# 1                Saint Louis, Missouri                              Yes
# 2                             Illinois                               No
# 3                             Missouri                              Yes
# 4                                Japan                              Yes
#
#   How much experience do you have programming? What class are you in?   \
# 0                            6 months - 1 year                Freshman
# 1                                   0-3 months                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have?  \
# 0                              1
# 1                              2
# 2                              1
# 3                              1
# 4                              1
#
#         How many pets and of which kind do you have?  \
# 0              I have two dogs both chihuahua mixes.
# 1                                                  0
# 2  I have two golden retrievers, Ellie and Amber....
# 3                                                  0
# 4                                            No pets
#
#   What is your favorite type of food? Where do you live?  ...  \
# 0   Pasta but fish is a close second.          On campus  ...
# 1                           Hot wings         Off campus  ...
# 2                            Mexican.          On campus  ...
# 3                          Vietnamese         Off campus  ...
# 4                               Pasta          On campus  ...
#
#   What is your favorite TV show? What is your favorite video game?  \
# 0                   Breaking Bad                     Rocket League
# 1                 Criminal Minds                          Valorant
# 2                      The Wire.                  Pokémon White 2.
# 3                            NaN                               NaN
# 4                            NaN                       Spiderman 2
#
#           What is your favorite book?  \
# 0                   The Scythe series
# 1    A Little life by Hanya Yanaghara
# 2  "Surprised by Joy" by C. S. Lewis.
# 3                                 NaN
# 4                                 NaN
#
#                      Why are you taking this class?   \
# 0      Its a requirement for the data science major.
# 1  I have an interest in programming. I enjoy lea...
# 2  Transfer course requirements for the Universit...
# 3                                      Applicability
# 4          I'm trying to get a minor in data science
#
#     Whats your favorite bash command? country/state Dogs Cats Other_pets  \
# 0                                  ls      Missouri    1    0          0
# 1                                 NaN           USA    0    0          0
# 2  <git push> by far, too satisfying.           USA    0    0          0
# 3                                 NaN      Missouri    0    0          0
# 4                                  ls         Japan    0    0          0
#
#   Favorite Cuisine
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 23 columns]

# %%
#5
Major = {'data science' : 'Computer Science',
         'Nursing' : 'Nursing',
         'comp sci' : 'computer science',
          'International Business (Graduated)' : 'political science',
          'Health Sciences' : 'Health Sciences',
          'Finance' : 'business',
          'Forensic Science' : 'Forensic Science',
          'Biochemistry' : 'Biochemistry',
          }

class_survey_df['Major'] = class_survey_df['What is your major?'].map(Major)
class_survey_df['Major']
# Out:
# 0                   NaN
# 1               Nursing
# 2                   NaN
# 3          Biochemistry
# 4       Health Sciences
# 5      computer science
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 10                  NaN
# 11    political science
# 12                  NaN
# 13                  NaN
# 14     Computer Science
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# Name: Major, dtype: object

# %%
#6
class_survey_df['How old are you?'] = class_survey_df['How old are you?'].str.replace('18 years old', '18')
class_survey_df['How old are you?'] = class_survey_df['How old are you?'].str.replace('19 turning 20 on Febuary 28', '19')
class_survey_df.head()
# Out:
#                     Timestamp What is your name?  \
# 0   2024/01/29 6:34:23 PM CST      Gavin Edwards
# 1   2024/01/29 6:46:07 PM CST                NaN
# 2   2024/01/29 7:45:39 PM CST        Connor Love
# 3   2024/01/29 7:47:12 PM CST               Liam
# 4  2024/01/29 10:45:38 PM CST  Aarushi Choudhary
#
#   What state/country were you born in? Are you working while in school?  \
# 0                             Missouri                              Yes
# 1                Saint Louis, Missouri                              Yes
# 2                             Illinois                               No
# 3                             Missouri                              Yes
# 4                                Japan                              Yes
#
#   How much experience do you have programming? What class are you in?   \
# 0                            6 months - 1 year                Freshman
# 1                                   0-3 months                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have?  \
# 0                              1
# 1                              2
# 2                              1
# 3                              1
# 4                              1
#
#         How many pets and of which kind do you have?  \
# 0              I have two dogs both chihuahua mixes.
# 1                                                  0
# 2  I have two golden retrievers, Ellie and Amber....
# 3                                                  0
# 4                                            No pets
#
#   What is your favorite type of food? Where do you live?  ...  \
# 0   Pasta but fish is a close second.          On campus  ...
# 1                           Hot wings         Off campus  ...
# 2                            Mexican.          On campus  ...
# 3                          Vietnamese         Off campus  ...
# 4                               Pasta          On campus  ...
#
#   What is your favorite video game?         What is your favorite book?  \
# 0                     Rocket League                   The Scythe series
# 1                          Valorant    A Little life by Hanya Yanaghara
# 2                  Pokémon White 2.  "Surprised by Joy" by C. S. Lewis.
# 3                               NaN                                 NaN
# 4                       Spiderman 2                                 NaN
#
#                      Why are you taking this class?   \
# 0      Its a requirement for the data science major.
# 1  I have an interest in programming. I enjoy lea...
# 2  Transfer course requirements for the Universit...
# 3                                      Applicability
# 4          I'm trying to get a minor in data science
#
#     Whats your favorite bash command? country/state Dogs Cats Other_pets  \
# 0                                  ls      Missouri    1    0          0
# 1                                 NaN           USA    0    0          0
# 2  <git push> by far, too satisfying.           USA    0    0          0
# 3                                 NaN      Missouri    0    0          0
# 4                                  ls         Japan    0    0          0
#
#   Favorite Cuisine            Major
# 0              NaN              NaN
# 1              NaN          Nursing
# 2              NaN              NaN
# 3              NaN     Biochemistry
# 4              NaN  Health Sciences
#
# [5 rows x 24 columns]

# %%
#7
plt.hist(class_survey_df['How old are you?'])
plt.xlabel('Age')
plt.ylabel('No. of students')
#most of the students are either 18 or 19 all the students are 18 or older.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.hist(class_survey_df['How old are you?'])
#       2 plt.xlabel('Age')
#       3 plt.ylabel('No. of students')
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py:3236, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3211 @_copy_docstring_and_deprecators(Axes.hist)
#    3212 def hist(
#    3213     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3234     BarContainer | Polygon | list[BarContainer | Polygon],
#    3235 ]:
# -> 3236     return gca().hist(
#    3237         x,
#    3238         bins=bins,
#    3239         range=range,
#    3240         density=density,
#    3241         weights=weights,
#    3242         cumulative=cumulative,
#    3243         bottom=bottom,
#    3244         histtype=histtype,
#    3245         align=align,
#    3246         orientation=orientation,
#    3247         rwidth=rwidth,
#    3248         log=log,
#    3249         color=color,
#    3250         label=label,
#    3251         stacked=stacked,
#    3252         **({"data": data} if data is not None else {}),
#    3253         **kwargs,
#    3254     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py:6783, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6781 if orientation == "vertical":
#    6782     convert_units = self.convert_xunits
# -> 6783     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    6784          *map(convert_units, x[1:])]
#    6785 else:  # horizontal
#    6786     convert_units = self.convert_yunits
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py:2555, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2553     # Update from data if axis is already set but no unit is set yet.
#    2554     if axis is not None and data is not None and not axis.have_units():
# -> 2555         axis.update_units(data)
#    2556 for axis_name, axis in axis_map.items():
#    2557     # Return if no axis is set.
#    2558     if axis is None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axis.py:1712, in Axis.update_units(self, data)
#    1710 neednew = self.converter != converter
#    1711 self.converter = converter
# -> 1712 default = self.converter.default_units(data, self)
#    1713 if default is not None and self.units is None:
#    1714     self.set_units(default)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/category.py:216, in UnitData.update(self, data)
#     213 convertible = True
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#     219         convertible = self._str_is_convertible(val)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/_api/__init__.py:91, in check_isinstance(types, **kwargs)
#      89     names.remove("None")
#      90     names.append("None")
# ---> 91 raise TypeError(
#      92     "{!r} must be an instance of {}, not a {}".format(
#      93         k,
#      94         ", ".join(names[:-1]) + " or " + names[-1]
#      95         if len(names) > 1 else names[0],
#      96         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
#8
survey = class_survey_df.groupby('How many siblings do you have?').count()
survey.reset_index(inplace=True)
fig, ax = plt.subplots()
ax.pie(survey['What is your name?'],labels = survey['How many siblings do you have?'], autopct='%1.0f%%')
#most of the students have 1 sbling and the same amount of students have 3 and 4.
# Out:
# ([<matplotlib.patches.Wedge at 0x13c3974c0>,
#   <matplotlib.patches.Wedge at 0x13c3973d0>,
#   <matplotlib.patches.Wedge at 0x13c397f10>,
#   <matplotlib.patches.Wedge at 0x13c3a65e0>,
#   <matplotlib.patches.Wedge at 0x13c3a6c70>],
#  [Text(0.3010292715984893, 1.058008212463818, '1'),
#   Text(-1.0257194238946143, -0.3973659062442328, '2'),
#   Text(-0.10149507400841275, -1.095307605174011, '3'),
#   Text(0.3010294078030684, -1.058008173710267, '4'),
#   Text(0.9352389226549122, -0.5790752606969836, '5+')],
#  [Text(0.16419778450826686, 0.5770953886166279, '41%'),
#   Text(-0.559483322124335, -0.2167450397695815, '29%'),
#   Text(-0.055360949459134216, -0.5974405119130968, '6%'),
#   Text(0.16419785880167365, -0.5770953674783273, '6%'),
#   Text(0.5101303214481339, -0.3158592331074455, '18%')])

# %%
#9
work= class_survey_df.groupby('Are you working while in school?').count()
work.reset_index(inplace=True)
fig, ax = plt.subplots()
ax.pie(work['country/state'],labels = work['Are you working while in school?'], autopct='%1.0f%%')
#most students are working while in school
# Out:
# ([<matplotlib.patches.Wedge at 0x16b04d670>,
#   <matplotlib.patches.Wedge at 0x16b04d580>],
#  [Text(0.7070663355909782, 0.8426489168532447, 'No'),
#   Text(-0.7070663355909786, -0.8426489168532442, 'Yes')],
#  [Text(0.38567254668598805, 0.4596266819199516, '28%'),
#   Text(-0.3856725466859883, -0.4596266819199513, '72%')])

# %%
#10
country = class_survey_df.groupby('What state/country were you born in?').count()
country.reset_index(inplace=True)
fig, ax = plt.subplots()
ax.pie(country['What state/country were you born in?'],labels = survey['country'], autopct='%1.0f%%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       2 country.reset_index(inplace=True)
#       3 fig, ax = plt.subplots()
# ----> 4 ax.pie(country['What state/country were you born in?'],labels = survey['country'], autopct='%1.0f%%')
#
# NameError: name 'survey' is not defined
