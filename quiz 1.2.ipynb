# %%
months =  ["January","February","March","April","May","June","July","August","September","October","November","December"] 
for month in months:
  if month == "December":
    print(month + "is my birthday")
# Out:
# Decemberis my birthday

# %% [markdown]
# ![CCCCE9A2-CADB-4221-9815-A07D9BB4C444.jpeg](attachment:836aad43-7026-418e-b4a4-187d3cfce57d.jpeg)

# %% [markdown]
# ![DEB84A5D-22AF-44A2-A1DC-4873281EB6CC.jpeg](attachment:2f804a07-7a7c-461d-ae76-d397e9898622.jpeg)

# %%
# the tree output displays my repos and the professors repos it also displays the different files under each, Like the homeowrk, class notes, etc.
